# %% [markdown]
# ### Importing Necessary library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans,DBSCAN,AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
airline_data = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
airline_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### Data Understanding

# %%
del airline_data['ID#']

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %% [markdown]
# ### Model building

# %%
std_scale = StandardScaler()
scaled_df = std_scale.fit_transform(airline_data)
scaled_df = pd.DataFrame(scaled_df,columns=airline_data.columns)
scaled_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Finding optimal number of K

# %%
wcss = []
for i in range(1,11):
    kmean_model = KMeans(n_clusters=i)
    kmean_model.fit_predict(scaled_df)
    wcss.append(kmean_model.inertia_)

# %%
wcss
# Out:
# [43989.000000000095,
#  35409.51662986136,
#  30899.216408790628,
#  27154.035327088164,
#  25179.9049563279,
#  21470.93959900209,
#  18893.59434829801,
#  17316.78205595397,
#  15966.023853642984,
#  14727.935166347457]

# %%
plt.plot(range(1,11),wcss)
plt.show()

# %% [markdown]
# #### Building Model K = 2

# %%
kmean_cluster = KMeans(n_clusters=2,).fit_predict(scaled_df)

# %%
airline_data['cluster_k2'] = kmean_cluster
airline_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.scatter(airline_data['cluster_k2'],airline_data['Balance'],c=airline_data['cluster_k2'])
plt.show()

# %% [markdown]
# ### Using Hierarichal clustering

# %%
plt.figure(figsize=(15,10))
dendogram = sch.dendrogram(sch.linkage(scaled_df,'single'))
plt.show()

# %%
h_cluster = AgglomerativeClustering(n_clusters=2,affinity='euclidean',linkage='single')

# %%
y_pred = h_cluster.fit_predict(scaled_df)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cluster_hc = pd.DataFrame(y_pred,columns=['cluster_hc'])
cluster_hc
# Out:
#       cluster_hc
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3994           0
# 3995           0
# 3996           0
# 3997           0
# 3998           0
#
# [3999 rows x 1 columns]

# %%
cluster_hc.value_counts()
# Out:
# cluster_hc
# 0             3998
# 1                1
# dtype: int64

# %%
airline_data['cluster_hc'] = cluster_hc

# %%
airline_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_data[airline_data['cluster_hc'] == 0]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_data[airline_data['cluster_hc'] == 1]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3583   160114         500          1          1          1        71954
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3583           86              30817               53               1373
#
#       Award?  cluster_k2  cluster_hc
# 3583       1           0           1

# %% [markdown]
# ### Use DBSCAN

# %%
dbscan = DBSCAN(eps=1,min_samples=5)
y_pred_db = dbscan.fit_predict(scaled_df)
y_pred_db
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
airline_data['cluster_db'] = y_pred_db

# %%
airline_data.cluster_db.unique()
# Out:
# array([ 0,  1, -1,  2,  3,  4,  5])

# %%
airline_data.cluster_db.value_counts()
# Out:
#  0    2319
#  1    1093
# -1     554
#  2      13
#  5       9
#  3       6
#  4       5
# Name: cluster_db, dtype: int64

# %%
airline_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.scatter(airline_data['cluster_db'],airline_data['Balance'],c=airline_data['cluster_db'])
plt.show()
