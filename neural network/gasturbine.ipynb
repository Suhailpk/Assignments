# %% [markdown]
# ### importing necessary libraries

# %%
import pandas as pd

# %%
df = pd.read_csv('gas_turbines.csv')
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df.dtypes
# Out:
# AT      float64
# AP      float64
# AH      float64
# AFDP    float64
# GTEP    float64
# TIT     float64
# TAT     float64
# TEY     float64
# CDP     float64
# CO      float64
# NOX     float64
# dtype: object

# %%
df.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df.std()
# Out:
# AT       7.574323
# AP       6.410760
# AH      13.793439
# AFDP     0.760197
# GTEP     4.173916
# TIT     16.527806
# TAT      7.866803
# TEY     15.829717
# CDP      1.103196
# CO       2.222206
# NOX     10.470586
# dtype: float64

# %%
X = df.drop(['TEY'],axis=1)
y = df[['TEY']]

# %% [markdown]
# **standardizing inputs**

# %%
std_scale = StandardScaler()
scaled_X = std_scale.fit_transform(X)
scaled_X = pd.DataFrame(scaled_X,columns=X.columns)
scaled_X
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             CDP        CO       NOX
# 0     -1.357331  0.532012  1.387845
# 1     -1.363676  0.568733  1.393002
# 2     -1.360957  0.552938  1.363586
# 3     -1.356424  0.548933  1.382878
# 4     -1.350985  0.574179  1.348591
# ...         ...       ...       ...
# 15034 -1.543161  1.145792  1.085751
# 15035 -1.513247  1.293578  1.119943
# 15036 -1.467922  2.695925  2.170062
# 15037 -1.422598  1.924683  2.391165
# 15038 -1.377273  1.354150  2.321539
#
# [15039 rows x 10 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split(scaled_X,y,test_size=0.20,random_state=12)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((12031, 10), (3008, 10), (12031, 1), (3008, 1))

# %% [markdown]
# ### Model building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=50, activation = 'relu',input_dim = 10))
model.add(Dense(units = 25, activation = 'relu'))
model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                550
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_2 (Dense)             (None, 10)                260
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2,096
# Trainable params: 2,096
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mse'])

# %%
X_train.shape
# Out:
# (12031, 10)

# %%
model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 376/376 [==============================] - 1s 2ms/step - loss: 55.7500 - mse: 5723.4419
# Epoch 2/50
# 376/376 [==============================] - 1s 2ms/step - loss: 6.8559 - mse: 114.6890
# Epoch 3/50
# 376/376 [==============================] - 1s 2ms/step - loss: 4.1959 - mse: 57.8336
# Epoch 4/50
# 376/376 [==============================] - 1s 2ms/step - loss: 2.9193 - mse: 30.4025
# Epoch 5/50
# 376/376 [==============================] - 1s 2ms/step - loss: 2.1840 - mse: 16.3652
# Epoch 6/50
# 376/376 [==============================] - 1s 2ms/step - loss: 1.6588 - mse: 9.2710
# Epoch 7/50
# 376/376 [==============================] - 1s 2ms/step - loss: 1.3642 - mse: 5.9501
# Epoch 8/50
# 376/376 [==============================] - 1s 2ms/step - loss: 1.1348 - mse: 3.9438
# Epoch 9/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.9796 - mse: 2.8010
# Epoch 10/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.8898 - mse: 2.1387
# Epoch 11/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.8166 - mse: 1.7288
# Epoch 12/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.7574 - mse: 1.4122
# Epoch 13/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.7042 - mse: 1.2250
# Epoch 14/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6802 - mse: 1.1041
# Epoch 15/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.6412 - mse: 0.9927
# Epoch 16/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6320 - mse: 0.9483
# Epoch 17/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.6280 - mse: 0.9024
# Epoch 18/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.6054 - mse: 0.8198
# Epoch 19/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5948 - mse: 0.8152
# Epoch 20/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6000 - mse: 0.8045
# Epoch 21/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5687 - mse: 0.7091
# Epoch 22/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5849 - mse: 0.7332
# Epoch 23/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5645 - mse: 0.6807
# Epoch 24/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5305 - mse: 0.6105
# Epoch 25/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5515 - mse: 0.6351
# Epoch 26/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5642 - mse: 0.6451
# Epoch 27/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5329 - mse: 0.5808
# Epoch 28/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5593 - mse: 0.6348
# Epoch 29/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5550 - mse: 0.6180
# Epoch 30/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5410 - mse: 0.5849
# Epoch 31/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5293 - mse: 0.5665
# Epoch 32/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5514 - mse: 0.5898
# Epoch 33/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5310 - mse: 0.5611
# Epoch 34/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5073 - mse: 0.5195
# Epoch 35/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5068 - mse: 0.5161
# Epoch 36/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5172 - mse: 0.5220
# Epoch 37/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5160 - mse: 0.5249
# Epoch 38/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5305 - mse: 0.5522
# Epoch 39/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5443 - mse: 0.5598
# Epoch 40/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5237 - mse: 0.5300
# Epoch 41/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5097 - mse: 0.5056
# Epoch 42/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5200 - mse: 0.5189
# Epoch 43/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5060 - mse: 0.5011
# Epoch 44/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5082 - mse: 0.5003
# Epoch 45/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5074 - mse: 0.5013
# Epoch 46/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5160 - mse: 0.5127
# Epoch 47/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5238 - mse: 0.5281
# Epoch 48/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4872 - mse: 0.4593
# Epoch 49/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5193 - mse: 0.5173
# Epoch 50/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5034 - mse: 0.4899

# %%
y_pred = model.predict(X_test)

# %%
model.evaluate(X_test,y_test)
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4929 - mse: 0.4708
# [0.4928828775882721, 0.4707741439342499]

# %%
output = y_test.copy()

# %%
output['y_pred_TEY'] = y_pred

# %%
output
# Out:
#           TEY  y_pred_TEY
# 4841   112.06  111.612526
# 6730   127.18  127.674721
# 7694   132.70  132.462860
# 9566   159.95  158.895996
# 6017   132.85  133.277649
# ...       ...         ...
# 8393   134.47  133.963028
# 5024   134.17  134.026703
# 4138   134.46  134.426636
# 3300   132.83  132.975708
# 12035  144.57  143.290237
#
# [3008 rows x 2 columns]
