# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, recall_score, precision_score,roc_auc_score,confusion_matrix

# %%
sales_data = pd.read_csv('SalaryData_Train(1).csv')
sales_data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
for col in sales_data.columns:
    print(sales_data[col].value_counts())
# Out:
# 36    852
# 31    851
# 33    837
# 34    836
# 37    828
#      ...
# 82      7
# 83      5
# 85      3
# 88      3
# 86      1
# Name: age, Length: 72, dtype: int64
#  Private             22285
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64
#  HS-grad         9840
#  Some-college    6677
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: education, dtype: int64
# 9     9840
# 10    6677
# 13    5044
# 14    1627
# 11    1307
# 7     1048
# 12    1008
# 6      820
# 4      557
# 15     542
# 5      455
# 8      377
# 16     375
# ...

# %%
sales_data.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
sales_data.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
features = ['workclass', 'education','maritalstatus','occupation', 'relationship', 'race', 'sex', 'native', 'Salary']
def label_encoder(data,label):
    le = LabelEncoder()
    data[label] = le.fit_transform(data[label])
for i in features:
    label_encoder(sales_data,i)

# %%
sales_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# ### Model building

# %%
X_train = sales_data.iloc[:,:-1]
y_train = sales_data.iloc[:,-1:]

# %%
std_scale = StandardScaler()
scaled_X = std_scale.fit_transform(X_train)
X_train = pd.DataFrame(data = scaled_X,columns=X_train.columns)
X_train
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 0      0.042779   2.935947  -0.349827     1.128898       0.947877   -1.479030
# 1      0.880261   1.887645  -0.349827     1.128898      -0.387243   -0.734533
# 2     -0.033356  -0.208958   0.174805    -0.439733      -1.722362   -0.238202
# 3      1.108665  -0.208958  -2.448354    -1.224048      -0.387243   -0.238202
# 4     -0.794703  -0.208958  -0.349827     1.128898      -0.387243    0.754461
# ...         ...        ...        ...          ...            ...         ...
# 30156 -0.870838  -0.208958  -0.874459     0.736740      -0.387243    1.498958
# 30157  0.118914  -0.208958   0.174805    -0.439733      -0.387243    0.009964
# 30158  1.489339  -0.208958   0.174805    -0.439733       2.282996   -1.479030
# 30159 -1.251511  -0.208958   0.174805    -0.439733       0.947877   -1.479030
# 30160  1.032530   0.839343   0.174805    -0.439733      -0.387243   -0.734533
#
# ...

# %% [markdown]
# ### Preparing test datasets

# %%
sales_test_data = pd.read_csv('SalaryData_Test(1).csv')
sales_test_data
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
def label_encoder(data,label):
    le = LabelEncoder()
    data[label] = le.fit_transform(data[label])
for i in features:
    label_encoder(sales_test_data,i)

# %%
sales_test_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# #### building test data

# %%
X_test = sales_test_data.iloc[:,:-1]
y_test = sales_test_data.iloc[:,-1:]

# %%
std_scale = StandardScaler()
scaled_X = std_scale.fit_transform(X_test)
X_test = pd.DataFrame(data = scaled_X,columns=X_test.columns)
X_test
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 0     -1.029005  -0.222347  -2.423439    -1.216563       0.933187    0.002725
# 1     -0.057423  -0.222347   0.190172    -0.434898      -0.395463   -0.494789
# 2     -0.804794  -1.257126  -0.855272     0.737599      -0.395463    0.997755
# 3      0.391000  -0.222347   1.235617    -0.044066      -0.395463    0.002725
# 4     -0.356371  -0.222347  -2.684800    -1.607395       0.933187    0.251483
# ...         ...        ...        ...          ...            ...         ...
# 15055 -0.431108  -0.222347  -0.332550     1.128431       0.933187    0.748998
# 15056  0.017315  -0.222347  -0.332550     1.128431      -1.724114    0.748998
# 15057 -0.057423  -0.222347  -0.332550     1.128431      -0.395463    0.748998
# 15058  0.391000  -0.222347  -0.332550     1.128431      -1.724114   -1.489819
# 15059 -0.281634   0.812432  -0.332550     1.128431      -0.395463   -0.743547
#
# ...

# %% [markdown]
# ### Model testing and training

# %%
# %%time
svm_classifier = SVC()
svm_classifier.fit(X_train,y_train)
y_pred_test = svm_classifier.predict(X_test)
print('Accuracy   : ',accuracy_score(y_test,y_pred_test))
print('Precision  : ',precision_score(y_test,y_pred_test))
print('Recall     : ',recall_score(y_test,y_pred_test))
print('AUC        : ',roc_auc_score(y_test,y_pred_test))
conf = confusion_matrix(y_test,y_pred_test)
sns.heatmap(conf,annot=True)
plt.show()
# Out:
# Accuracy   :  0.846547144754316
# Precision  :  0.7592385218365062
# Recall     :  0.5497297297297298
# AUC        :  0.7464757803578226
# CPU times: user 43.1 s, sys: 16 ms, total: 43.1 s
# Wall time: 43.2 s

# %%
y_train.value_counts()
# Out:
# Salary
# 0         22653
# 1          7508
# dtype: int64

# %%
plt.pie(x = y_train.Salary.value_counts(),autopct='%2f')
plt.show()

# %% [markdown]
# ### TUNE SVM MODEL USING GridSearchCV

# %%
# %%time
grid_cv = GridSearchCV(estimator=svm_classifier, param_grid={
    'degree': range(1,5),
    'C':range(1,6)
})
grid_cv.fit(X_train,y_train)
# Out:
# CPU times: user 36min 18s, sys: 1.65 s, total: 36min 20s
# Wall time: 36min 23s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': range(1, 6), 'degree': range(1, 5)})

# %%
grid_cv.best_params_
# Out:
# {'C': 4, 'degree': 1}

# %%
grid_cv.best_score_
# Out:
# 0.8457944226735273

# %%
# %%time
svm_classifier = SVC(kernel='rbf',C = 4,degree=1)
svm_classifier.fit(X_train,y_train)
y_pred_test = svm_classifier.predict(X_test)
print('Accuracy   : ',accuracy_score(y_test,y_pred_test))
print('Precision  : ',precision_score(y_test,y_pred_test))
print('Recall     : ',recall_score(y_test,y_pred_test))
print('AUC        : ',roc_auc_score(y_test,y_pred_test))
conf = confusion_matrix(y_test,y_pred_test)
sns.heatmap(conf,annot=True)
plt.show()
# Out:
# Accuracy   :  0.8462815405046481
# Precision  :  0.7517266448564158
# Recall     :  0.5589189189189189
# AUC        :  0.7493978397411497
# CPU times: user 43.9 s, sys: 28 ms, total: 43.9 s
# Wall time: 44 s
